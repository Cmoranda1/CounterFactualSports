# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_ipo20 = pd.read_csv("JJvsIPO/2020Pos.csv")

# %%
df_jj20 = pd.read_csv("JJvsIPO/2020PosJJ.csv")

# %%
df_ipo_diff = df_ipo20[df_ipo20["AVoverAvg"] < 0]

# %%
df_ipo_diffjj = df_jj20[df_jj20["AVoverAvgIPO"] < 0]

# %%
df_ipo_diff
# Out:
#     Unnamed: 0  Rnd  Pick Tm_x                     Player Pos   Age      To  \
# 1            4    1     5  MIA    Tua Tagovailoa\TagoTu00  QB  22.0  2021.0
# 6           11    1    12  LVR   Henry Ruggs III\RuggHe00  WR  21.0  2021.0
# 13          19    1    20  JAX  K'Lavon Chaisson\ChaiKL00  DE  21.0  2021.0
#
#     AP1  PB    ...      Return_y                  Sector  \
# 1     0   0    ...        -0.129              Technology
# 6     0   0    ...        -0.613  Consumer Discretionary
# 13    0   0    ...         0.215             Health Care
#
#                               Industry        Country  Round_y  IPOMultiplier  \
# 1                 Software-Application  United States        1       0.435083
# 6   Internet & Direct Marketing Retail  United States        1       0.250000
# 13                       Biotechnology  United States        1       0.225000
#
#     AdjustedValueIPO  AvgValueIPO  AVoverAvgIPO  ReturnIPO
# ...

# %%
df_ipo_diffjj
# Out:
#      Unnamed: 0  Rnd  Pick Tm_x                          Player Pos   Age  \
# 37           53    2    54  BUF           A.J. Epenesa\EpenAJ00  DE  21.0
# 43           59    2    60  NWE              Josh Uche\UcheJo00  LB  21.0
# 50           66    3    67  DET          Julian Okwara\OkwaJu00  DE  22.0
# 59           75    3    76  TAM        Ke'Shawn Vaughn\VaugKe00  RB  23.0
# 62           79    3    80  LVR        Lynn Bowden Jr.\BowdLy00  WR  22.0
# 66           83    3    84  LAR          Terrell Lewis\LewiTe00  LB  22.0
# 69           86    3    87  NWE      Anfernee Jennings\JennAn00  LB  23.0
# 70           87    3    88  CLE         Jordan Elliott\ElliJo02  DT  22.0
# 74           92    3    93  TEN        Darrynton Evans\EvanDa02  RB  22.0
# 75           93    3    94  GNB         Josiah Deguara\DeguJo00  TE  23.0
# 76           94    3    95  DEN          McTelvin Agim\AgimMc00  DT  22.0
# 78           96    3    97  CLE         Jacob Phillips\PhilJa01  LB  21.0
# ...

# %%
df_ipo19 = pd.read_csv("JJvsIPO/2019Pos.csv")
df_jj19 = pd.read_csv("JJvsIPO/2019PosJJ.csv")
df_ipo_diff19 = df_ipo19[df_ipo19["AVoverAvg"] < 0]
df_ipo_diffjj19 = df_jj19[df_jj19["AVoverAvgIPO"] < 0]

# %%
df_ipo_diff19
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Rnd, Pick, Tm_x, Player, Pos, Age, To, AP1, PB, St, wAV, DrAV, G, Cmp, Att, Yds, TD, Int, Att.1, Yds.1, TD.1, Rec, Yds.2, TD.2, Solo, Int.1, Sk, College/Univ, Unnamed: 28, Round_x, Value, Tm_y, Year, Multiplier, AdjustedValue, AvgValue, AVoverAvg, Return_x, IPO Date, Symbol, Company Name, IPO Price, Current, Return_y, Sector, Industry, Country, Round_y, IPOMultiplier, AdjustedValueIPO, AvgValueIPO, AVoverAvgIPO, ReturnIPO]
# Index: []
#
# [0 rows x 54 columns]

# %%
df_ipo_diffjj19
# Out:
#      Unnamed: 0  Rnd  Pick Tm_x                      Player Pos  Age      To  \
# 25           29    1    30  NYG      Deandre Baker\BakeDe00  CB   22  2021.0
# 27           31    1    32  NWE       N'Keal Harry\HarrNK00  WR   21  2021.0
# 41           49    2    50  MIN      Irv Smith Jr.\SmitIr01  TE   21  2020.0
# 43           51    2    52  CIN        Drew Sample\SampDr00  TE   23  2021.0
# 48           57    2    58  DAL       Trysten Hill\HillTr00  DT   21  2021.0
# 49           58    2    59  IND    Parris Campbell\CampPa00  WR   22  2021.0
# 52           61    2    62  ARI      Andy Isabella\IsabAn00  WR   22  2021.0
# 65           78    3    79  LAR         David Long\LongDa02  CB   21  2021.0
# 69           82    3    83  PIT       Justin Layne\LaynJu00  CB   21  2021.0
# 70           83    3    84  KAN    Khalen Saunders\SaunKh00  DT   23  2021.0
# 77           91    3    92  NYJ        Chuma Edoga\EdogCh00   T   22  2021.0
# ...
